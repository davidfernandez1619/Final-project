# %% [markdown]
# # Scrapping LinkedIn profiles

# %%
import os
import requests
import re
import pandas as pd
from requests.exceptions import RequestException
import json
from pandas import json_normalize
import datetime

# %% [markdown]
# # Function that scrapes LinkedIn profiles

# %%
def scrape_linkedin_profile2(linkedin_profile_url: str):
    api_key = "2ZjHkun0Sq6KGa_o-4p7jg"
    header_dic = {"Authorization": f"Bearer {api_key}"}
    api_endpoint = "https://nubela.co/proxycurl/api/v2/linkedin"

    response = requests.get(
        api_endpoint, params={"url": linkedin_profile_url}, headers=header_dic
    )

    try:
        data = response.json()
        data = {
            k: v
            for k, v in data.items()
            if v not in ([], "", "", None)
            and k
            not in [
                "people_also_viewed",
                "recommendations",
                "similarly_named_profiles",
                "articles",
                "background_cover_image_url",
                "activities",
                "volunteer_work",
            ]
        }
        if data.get("groups"):
            for group_dict in data.get("groups"):
                group_dict.pop("profile_pic_url")

        return data

    except json.JSONDecodeError:

        return None

# %% [markdown]
# # Function that scrapes company's profiles

# %%
def scrape_linkedin_company_data(linkedin_company_url):
    api_key = "2ZjHkun0Sq6KGa_o-4p7jg"
    headers = {'Authorization': f'Bearer {api_key}'}

    api_endpoint_1 = 'https://nubela.co/proxycurl/api/linkedin/company'
    params_1 = {
        'url': linkedin_company_url,
        'use_cache': 'if-present',
    }
    response_1 = requests.get(api_endpoint_1, params=params_1, headers=headers)

    if response_1.status_code == 200:
        data = response_1.json()
        return data
    
    else:
        
        api_endpoint_2 = 'https://nubela.co/proxycurl/api/linkedin/school'
        params_2 = {
            'url': linkedin_company_url,  # Utiliza la misma URL
            'use_cache': 'if-present',
        }
        response_2 = requests.get(api_endpoint_2, params=params_2, headers=headers)

        if response_2.status_code == 200:
            data = response_2.json()
            return data
        else:
            print(f"Error al obtener datos de {linkedin_company_url} con la segunda opción.")
            return None

# %% [markdown]
# # Scraping and cleaning our dataframes

# %% [markdown]
# ## First dataframe: 2015-2016 class

# %%
df1 = pd.read_csv('/Users/davidfernandez/Desktop/clean/scrapped/2015-2016.csv') 

df1 = df1[df1['Link perfil'] != 'Link no existente']

df1 = df1.reset_index()

df1 = df1.drop('index', axis=1)

'''We open our CSV, containing the full name and URL of the profile of our students, and we remove all those
rows that don't contain the URL of the student, because our Selenium code couldn't scrap it'''
# Out:
# "We open our CSV, containing the full name and URL of the profile of our students, and we remove all those\nrows that don't contain the URL of the student, because our Selenium code couldn't scrap it"

# %%
df1["Datos escrapeados"] = df1["Link perfil"].apply(scrape_linkedin_profile2)

# We apply our function to the row of our dataframe that contains all the URLs of our students

# %%
valor_a_buscar = {'code': 404, 'description': 'Person profile does not exist', 'name': 'Not Found'}


filas_filtradas = df1.loc[df1['Datos escrapeados'] == valor_a_buscar]

# We identify those students whose data we couldn't scrap

indices_a_eliminar = filas_filtradas.index

df1 = df1.drop(indices_a_eliminar)

# And we take them out

# %%
df1 = df1.reset_index()

df1 = df1.drop('index', axis=1)

# We reset indexes and delete the column 'index'

# %%
normalized_data = pd.json_normalize(df1['Datos escrapeados']) 

# We create one column per key in our 'Datos escrapeados' column

# %%
df1 = pd.concat([df1, normalized_data], axis=1) # We apply those columns to our df1 dataframe

# %%
columnas_a_eliminar = ['Nombre', 'Primer apellido', 'Segundo apellido', 'Email universitario', 'Email personal', 'Datos escrapeados', 'public_identifier', 'profile_pic_url', 'first_name', 'last_name', 'full_name', 'headline', 'country', 'languages', 'education', 'occupation', 'connections', 'country_full_name', 'follower_count', 'summary', 'state', 'accomplishment_honors_awards', 'accomplishment_courses', 'accomplishment_projects', 'groups', 'accomplishment_publications', 'certifications', 'accomplishment_organisations', 'accomplishment_test_scores']


df1 = df1.drop(columns=columnas_a_eliminar)

# %%
df1 = df1.explode('experiences')

# We explode our lists in 'experiences' column, to have as many rows per student as experiences she/he has

# %%
df1 = df1.reset_index()

df1 = df1.drop('index', axis=1)

# We reset our indexes, to make it more clear

# %%
normalized_data1 = pd.json_normalize(df1['experiences']) 


df1 = pd.concat([df1, normalized_data1], axis=1) # We apply those columns to our df1 dataframe

# %%
df1.columns
# Out:
# Index(['Grado', 'Nombre completo', 'Link perfil', 'city', 'experiences',
#        'company', 'company_linkedin_profile_url', 'title', 'description',
#        'location', 'logo_url', 'starts_at.day', 'starts_at.month',
#        'starts_at.year', 'ends_at.day', 'ends_at.month', 'ends_at.year',
#        'ends_at', 'starts_at'],
#       dtype='object')

# %%
cols_a_eliminar = ['description', 'logo_url', 'ends_at', 'starts_at', 'experiences']                  
                   
df1 = df1.drop(cols_a_eliminar, axis=1)

# We get rid of unwanted columns

# %%
copi1 = df1.copy() # We create a copy of our dataframe just in case

# %%
copi1["Datos empresa"] = copi1["company_linkedin_profile_url"].apply(scrape_linkedin_company_data)

# We scrape all the data from each company
# Out:
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de nan con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2558499/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2558499/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2558499/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/15092653/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/9472/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/private-tutor con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1009/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/554396/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10622779/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/7389/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/5374816/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/12859083/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/5217216/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de nan con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/19088356/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/universidad-camilo-jos%C3%A9-cela con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/vanilla-seed/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/havas-media-espa%C3%B1a/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/lor%C3%A9al con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/640443/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/5266317/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/9295280/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10424531/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/5346208/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/839196/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3291480/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/682810/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10830149/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/20200212/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1840479/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1816/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1076318/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de nan con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/inforpress con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/la-f-brica-de-la-tele con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/accenture-interactive con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/joyer%C3%ADa-oliva con la segunda opción.
# Error al obtener datos de nan con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/39109954/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2967838/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/34722898/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/510754/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10966712/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3121613/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/18075742/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/37913931/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/64861959/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/15092653/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/ceu-business-school-madrid- con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/transfesa con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de nan con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/telecinco con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/instituto-cervantes con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/fundaci-n-colecci-n-thyssen-bornemisza con la segunda opción.
# Error al obtener datos de nan con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2426057/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3152353/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/938337/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/15092653/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/540234/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/540234/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/540234/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/540234/ con la segunda opción.
# Error al obtener datos de nan con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/school/universidad-camilo-jos%C3%A9-cela/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/non-stop-people-espa%C3%B1a con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/telef%C3%B3nica con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de nan con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/amcham-american-chamber-of-commerce- con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2816303/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/42942070/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/740718/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/740718/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/born-living-yoga con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3317295/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/28449229/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3764/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3765/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/5418/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/18849493/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/37425/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3114657/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1136170/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1840479/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/36384/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/36384/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/36384/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/5073216/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/peri%C3%B3dico-magisterio/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/non-stop-people-espa%C3%B1a con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/non-stop-people-espa%C3%B1a con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/telef%C3%B3nica/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de nan con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/dealz-espa%C3%B1a/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.

# %%
copii1 = copi1.copy()

# %%
normalized_data1 = pd.json_normalize(copii1['Datos empresa']) 


copii1 = pd.concat([copii1, normalized_data1], axis=1) # We apply those columns to our df1 dataframe

# %%
to_drop1 = ['linkedin_internal_id', 'specialities', 'Datos empresa', 'company_type', 'description', 'website', 'company_size', 'company_size_on_linkedin', 'founded_year', 'locations', 'name', 'tagline', 'universal_name_id', 'profile_pic_url', 'background_cover_image_url', 'search_id', 'similar_companies', 'affiliated_companies', 'updates', 'follower_count', 'acquisitions', 'exit_data', 'extra', 'funding_data', 'categories', 'hq.country', 'hq.city', 'hq.postal_code', 'hq.line_1', 'hq.is_hq', 'hq.state', 'hq']


copii1.drop(to_drop1, axis=1, inplace=True)

# %%
copii1['ends_at.day'].fillna('actualidad', inplace=True)
copii1['ends_at.month'].fillna('actualidad', inplace=True)
copii1['ends_at.year'].fillna('actualidad', inplace=True)

# If any of our ending columns have nulls, it means that that person is still working there

# %%
copii1.dropna(subset=['starts_at.day', 'starts_at.month', 'starts_at.year'], inplace=True)

# We get rid of all our experiences whose start date is null

# %%
# Combines the columns of start date and end date into 'end date'
copii1['Fecha inicio'] = copii1.apply(lambda x: pd.to_datetime(f"{int(x['starts_at.year'])}-{int(x['starts_at.month'])}-01"), axis=1)
copii1['Fecha fin'] = copii1.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else pd.to_datetime(f"{int(x['ends_at.year'])}-{int(x['ends_at.month'])}-01"), axis=1)
copii1['Duración (meses)'] = copii1.apply(lambda x: (datetime.datetime.now() - x['Fecha inicio']).days // 30 if x['ends_at.year'] == 'actualidad' else (x['Fecha fin'] - x['Fecha inicio']).days // 30, axis=1)
copii1['Fecha fin'] = copii1.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else x['Fecha fin'], axis=1)
copii1.drop(['location', 'starts_at.year', 'starts_at.day', 'starts_at.month', 'ends_at.day', 'ends_at.month', 'ends_at.year'], axis=1, inplace=True)

# %%
copii1.rename(columns={'company': 'Empresa', 'title': 'Puesto', 'city': 'Ciudad', 'industry': 'Sector'}, inplace=True)

# We rename some columns in spanish

# %%
new_order = ['Grado', 'Nombre completo', 'Link perfil', 'Puesto', 'Empresa', 'Sector', 'Ciudad', 'Fecha inicio', 'Fecha fin', 'Duración (meses)']

copii1 = copii1[new_order]

# We finally change the orders of some columns to make them more comprehensible

# %%
df1 = copii1.reset_index()

df1 = df1.drop('index', axis=1)

# %%
df1.to_csv('/Users/davidfernandez/Desktop/clean/experience/2015-2016.csv', index=False)

# %% [markdown]
# ## Second dataframe: 2016-2017 class

# %%
df2 = pd.read_csv('/Users/davidfernandez/Desktop/clean/scrapped/2016-2017.csv') 

df2 = df2[df2['Link perfil'] != 'Link no existente']

df2 = df2.reset_index()

df2 = df2.drop('index', axis=1)

# %%
df2["Datos escrapeados"] = df2["Link perfil"].apply(scrape_linkedin_profile2)

# %%
valor_a_buscar = {'code': 404, 'description': 'Person profile does not exist', 'name': 'Not Found'}


filas_filtradas = df2.loc[df2['Datos escrapeados'] == valor_a_buscar]

# We identify those students whose data we couldn't scrap

indices_a_eliminar = filas_filtradas.index

df2 = df2.drop(indices_a_eliminar)

# And we take them out

# %%
copi2 = df2.copy()

# %%
copi2 = copi2.reset_index()
copi2 = copi2.drop('index', axis=1)

normalized_data = pd.json_normalize(copi2['Datos escrapeados'])

copi2 = pd.concat([copi2, normalized_data], axis=1)

columnas_a_eliminar = ['Nombre', 'Primer apellido', 'Segundo apellido', 'Email universitario', 'Email personal', 'Datos escrapeados', 'public_identifier', 'profile_pic_url', 'first_name', 'last_name', 'full_name', 'headline', 'country', 'languages', 'education', 'occupation', 'connections', 'country_full_name', 'follower_count', 'summary', 'state', 'accomplishment_honors_awards', 'accomplishment_courses', 'accomplishment_projects', 'groups', 'accomplishment_publications', 'certifications', 'accomplishment_organisations', 'accomplishment_test_scores']

copi2 = copi2.drop(columns=columnas_a_eliminar)

copi2 = copi2.explode('experiences')

copi2 = copi2.reset_index()
copi2 = copi2.drop('index', axis=1)

normalized_data1 = pd.json_normalize(copi2['experiences'])

copi2 = pd.concat([copi2, normalized_data1], axis=1)

cols_a_eliminar = ['description', 'logo_url', 'ends_at', 'starts_at', 'experiences']

copi2 = copi2.drop(cols_a_eliminar, axis=1)

# %%
copi2['ends_at.day'].fillna('actualidad', inplace=True)
copi2['ends_at.month'].fillna('actualidad', inplace=True)
copi2['ends_at.year'].fillna('actualidad', inplace=True)

copi2.dropna(subset=['starts_at.day', 'starts_at.month', 'starts_at.year'], inplace=True)

copi2['Fecha inicio'] = copi2.apply(lambda x: pd.to_datetime(f"{int(x['starts_at.year'])}-{int(x['starts_at.month'])}-01"), axis=1)
copi2['Fecha fin'] = copi2.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else pd.to_datetime(f"{int(x['ends_at.year'])}-{int(x['ends_at.month'])}-01"), axis=1)

copi2['Duración (meses)'] = copi2.apply(lambda x: (datetime.datetime.now() - x['Fecha inicio']).days // 30 if x['ends_at.year'] == 'actualidad' else (x['Fecha fin'] - x['Fecha inicio']).days // 30, axis=1)

copi2['Fecha fin'] = copi2.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else x['Fecha fin'], axis=1)

copi2.drop(['location', 'starts_at.year', 'starts_at.day', 'starts_at.month', 'ends_at.day', 'ends_at.month', 'ends_at.year'], axis=1, inplace=True)

copi2.rename(columns={'company': 'Empresa', 'title': 'Puesto', 'city': 'Ciudad'}, inplace=True)

copi2 = copi2.reset_index()
copi2 = copi2.drop('index', axis=1)

# %%
copi2["company_linkedin_profile_url"] = copi2["company_linkedin_profile_url"].apply(scrape_linkedin_company_data)
# Out:
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/espa%C3%B1a-fascinante con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/camara-de-comercio-de-espana-en-belgica-y-luxemburgo con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/aut-noma_6 con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/18969716/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/74743322/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/73240163/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/39322410/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2271/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://it.linkedin.com/company/accenture-interactive con la segunda opción.
# Error al obtener datos de https://it.linkedin.com/company/accenture-interactive con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/cl%C3%ADnica-ros-dental/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/actelion-%27now-janssen-pulmonary-hypertension%27 con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/85405652/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/632086/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2238213/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2816303/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/42942070/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/740718/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/740718/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1840479/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1840479/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10917218/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10187994/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/dealz-espa%C3%B1a/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/el-espa%C3%B1ol con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1033/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/19179973/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/19179973/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3121613/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1701217/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/362258/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/40442775/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1208590/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/920608/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3285839/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3152353/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/latinstock con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/latinstock con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/11420147/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10647746/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/319336/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/42157/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/lor%C3%A9al con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/300389/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/300389/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/300389/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1259/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10273145/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/5064024/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/5258425/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1662/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2500/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/11164328/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/restaurante-la-m%C3%A1quina-s-a con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1207/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2748/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/73337666/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1116/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/28597110/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/28597110/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/16177955/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/porsche-ib%C3%A9rica/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/porsche-ib%C3%A9rica/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/g2-worldwide100430-001168 con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/federaci%C3%B3n-de-madrid-de-voleibol con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.

# %%
copii2 = copi2.copy()

# %%
normalized_data1 = pd.json_normalize(copii2['company_linkedin_profile_url']) 


copii2 = pd.concat([copii2, normalized_data1], axis=1)

# %%
to_drop1 = ['linkedin_internal_id', 'specialities', 'company_linkedin_profile_url', 'company_type', 'description', 'website', 'company_size', 'company_size_on_linkedin', 'founded_year', 'locations', 'name', 'tagline', 'universal_name_id', 'profile_pic_url', 'background_cover_image_url', 'search_id', 'similar_companies', 'affiliated_companies', 'updates', 'follower_count', 'acquisitions', 'exit_data', 'extra', 'funding_data', 'categories', 'hq.country', 'hq.city', 'hq.postal_code', 'hq.line_1', 'hq.is_hq', 'hq.state', 'hq']


copii2.drop(to_drop1, axis=1, inplace=True)

# %%
copii2.rename(columns={'industry': 'Sector'}, inplace=True)

# %%
new_order = ['Grado', 'Nombre completo', 'Link perfil', 'Puesto', 'Empresa', 'Sector', 'Ciudad', 'Fecha inicio', 'Fecha fin', 'Duración (meses)']

copii2 = copii2[new_order]

# %%
copii2.to_csv('/Users/davidfernandez/Desktop/clean/experience/2016-2017.csv', index=False)

# %% [markdown]
# ## Third dataframe: 2017-2018 class

# %%
df3 = pd.read_csv('/Users/davidfernandez/Desktop/clean/scrapped/2017-2018.csv') 

df3 = df3[df3['Link perfil'] != 'Link no existente']

df3 = df3.reset_index()

df3 = df3.drop('index', axis=1)

# %%
df3["Datos escrapeados"] = df3["Link perfil"].apply(scrape_linkedin_profile2)

# %%
valor_a_buscar = {'code': 404, 'description': 'Person profile does not exist', 'name': 'Not Found'}


filas_filtradas = df3.loc[df3['Datos escrapeados'] == valor_a_buscar]

# We identify those students whose data we couldn't scrap

indices_a_eliminar = filas_filtradas.index

df3 = df3.drop(indices_a_eliminar)

# And we take them out

# %%
copi3 = df3.copy()

# %%
copi3 = copi3.reset_index()
copi3 = copi3.drop('index', axis=1)

normalized_data = pd.json_normalize(copi3['Datos escrapeados'])

copi3 = pd.concat([copi3, normalized_data], axis=1)

columnas_a_eliminar = ['Email universitario', 'Email personal', 'Datos escrapeados', 'public_identifier', 'profile_pic_url', 'first_name', 'last_name', 'full_name', 'headline', 'country', 'languages', 'education', 'occupation', 'connections', 'country_full_name', 'follower_count', 'summary', 'state', 'accomplishment_honors_awards', 'accomplishment_courses', 'accomplishment_projects', 'groups', 'accomplishment_publications', 'certifications', 'accomplishment_organisations', 'accomplishment_test_scores']

copi3 = copi3.drop(columns=columnas_a_eliminar)

copi3 = copi3.explode('experiences')

copi3 = copi3.reset_index()
copi3 = copi3.drop('index', axis=1)

normalized_data1 = pd.json_normalize(copi3['experiences'])

copi3 = pd.concat([copi3, normalized_data1], axis=1)

cols_a_eliminar = ['description', 'logo_url', 'ends_at', 'starts_at', 'experiences']

copi3 = copi3.drop(cols_a_eliminar, axis=1)

# %%
copi3['ends_at.day'].fillna('actualidad', inplace=True)
copi3['ends_at.month'].fillna('actualidad', inplace=True)
copi3['ends_at.year'].fillna('actualidad', inplace=True)

copi3.dropna(subset=['starts_at.day', 'starts_at.month', 'starts_at.year'], inplace=True)

copi3['Fecha inicio'] = copi3.apply(lambda x: pd.to_datetime(f"{int(x['starts_at.year'])}-{int(x['starts_at.month'])}-01"), axis=1)
copi3['Fecha fin'] = copi3.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else pd.to_datetime(f"{int(x['ends_at.year'])}-{int(x['ends_at.month'])}-01"), axis=1)

copi3['Duración (meses)'] = copi3.apply(lambda x: (datetime.datetime.now() - x['Fecha inicio']).days // 30 if x['ends_at.year'] == 'actualidad' else (x['Fecha fin'] - x['Fecha inicio']).days // 30, axis=1)

copi3['Fecha fin'] = copi3.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else x['Fecha fin'], axis=1)

copi3.drop(['location', 'starts_at.year', 'starts_at.day', 'starts_at.month', 'ends_at.day', 'ends_at.month', 'ends_at.year'], axis=1, inplace=True)

copi3.rename(columns={'company': 'Empresa', 'title': 'Puesto', 'city': 'Ciudad'}, inplace=True)

copi3 = copi3.reset_index()
copi3 = copi3.drop('index', axis=1)

# %%
copi3["Datos empresa"] = copi3["company_linkedin_profile_url"].apply(scrape_linkedin_company_data)
# Out:
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/non-stop-people-espa%C3%B1a con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/popeyes-espa%%C3%%B1a con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/caf%%C3%%A9-leather-supply con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/lor%C3%A9al con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2614/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3479359/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3479359/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3479359/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3479359/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3574819/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/90792496/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/122236/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2357057/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/69279/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/69279/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2666838/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2398775/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/11240313/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1248161/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/lor%C3%A9al/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/lor%C3%A9al/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/lor%C3%A9al/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/fundaci%%C3%%B3n-repsol con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/porsche-ib%C3%A9rica/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/porsche-ib%C3%A9rica/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/porsche-ib%C3%A9rica/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/porsche-ib%C3%A9rica/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/porsche-ib%C3%A9rica/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/11864992/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/40619335/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2765374/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/9273705/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/hogarth-worldwide con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/vccp-kin con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/lor%C3%A9al con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/espa%C3%B1a-fascinante/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/cl%C3%BAster-industria-defensa/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/13154/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/4059/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/4059/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/4059/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1060785/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10187994/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/4983990/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/30746/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/30746/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/35649228/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/9869703/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/9869703/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2691523/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2109978/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/lor%C3%A9al/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3121613/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3121613/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/14853/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/706324/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/wonder-sweden con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/fundaci%C3%B3n-museo-naval/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/asociaci%C3%B3n-art%C3%ADstica-m%C3%BAsica-callada-a-a-m-c con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/qms-comunicaci%C3%B3n con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/financiera-el-corte-ingl%C3%A9s-e.f.c-s.a./ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3121613/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/37425/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/15092653/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/30746/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1118916/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/cvne-compa%C3%B1%C3%ADavin%C3%ADcoladelnortedeespa%C3%B1a con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/school/universidad-nacional-de-educaci%C3%B3n-a-distancia---u.n.e.d./ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/financiera-el-corte-ingl%C3%A9s-e.f.c-s.a. con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/financiera-el-corte-ingl%C3%A9s-e.f.c-s.a. con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/telef%C3%B3nica con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/el-espa%C3%B1ol con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/el-espa%%C3%%B1ol con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/el-espa%%C3%%B1ol con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/freelance-translator_10 con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/flying-tiger-espa%C3%B1a/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1207/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2748/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/73337666/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1116/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/28597110/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/28597110/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/16177955/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/factor%C3%ADa-plural/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2607716/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10373120/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2030583/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/798828/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10958463/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/18357901/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/15092653/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/15092653/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/42157/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/873253/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/espa%C3%B1a-fascinante con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/fundaci-n-s-ndrome-de-down-de-madrid con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/lor%C3%A9al/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3544511/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10330625/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/29277388/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/833000/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/772471/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/18287884/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/788331/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10942967/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/56430/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/56430/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3121613/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/39045275/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/40327981/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.

# %%
copii3 = copi3.copy()

# %%
normalized_data1 = pd.json_normalize(copii3['Datos empresa']) 

copii3 = pd.concat([copii3, normalized_data1], axis=1)

# %%
to_drop1 = ['linkedin_internal_id', 'specialities', 'Datos empresa', 'company_type', 'description', 'website', 'company_size', 'company_size_on_linkedin', 'founded_year', 'locations', 'name', 'tagline', 'universal_name_id', 'profile_pic_url', 'background_cover_image_url', 'search_id', 'similar_companies', 'affiliated_companies', 'updates', 'follower_count', 'acquisitions', 'exit_data', 'extra', 'funding_data', 'categories', 'hq.country', 'hq.city', 'hq.postal_code', 'hq.line_1', 'hq.is_hq', 'hq.state', 'hq']


copii3.drop(to_drop1, axis=1, inplace=True)

# %%
copii3.rename(columns={'industry': 'Sector'}, inplace=True)

new_order = ['Grado', 'Nombre completo', 'Link perfil', 'Puesto', 'Empresa', 'Sector', 'Ciudad', 'Fecha inicio', 'Fecha fin', 'Duración (meses)']

copii3 = copii3[new_order]

# %%
copii3.to_csv('/Users/davidfernandez/Desktop/clean/experience/2017-2018.csv', index=False)

# %% [markdown]
# ## Fifth dataframe: 2019-2020 class

# %%
df5 = pd.read_csv('/Users/davidfernandez/Desktop/clean/scrapped/2019-2020.csv')

df5 = df5[df5['Link perfil'] != 'Link no existente']

df5 = df5.reset_index()

df5 = df5.drop('index', axis=1)

# %%
df5["Datos escrapeados"] = df5["Link perfil"].apply(scrape_linkedin_profile2)

# %%
valor_a_buscar = {'code': 404, 'description': 'Person profile does not exist', 'name': 'Not Found'}


filas_filtradas = df5.loc[df5['Datos escrapeados'] == valor_a_buscar]

# We identify those students whose data we couldn't scrap

indices_a_eliminar = filas_filtradas.index

df5 = df5.drop(indices_a_eliminar)

# And we take them out

# %%
copi5 = df5.copy()

# %%
copi5 = copi5.reset_index()
copi5 = copi5.drop('index', axis=1)

normalized_data = pd.json_normalize(copi5['Datos escrapeados'])

copi5 = pd.concat([copi5, normalized_data], axis=1)

columnas_a_eliminar = ['Email universitario', 'Email personal', 'Datos escrapeados', 'public_identifier', 'profile_pic_url', 'first_name', 'last_name', 'full_name', 'headline', 'country', 'languages', 'education', 'occupation', 'connections', 'country_full_name', 'follower_count', 'summary', 'state', 'accomplishment_honors_awards', 'accomplishment_courses', 'accomplishment_projects', 'groups', 'accomplishment_publications', 'certifications', 'accomplishment_organisations', 'accomplishment_test_scores']

copi5 = copi5.drop(columns=columnas_a_eliminar)

copi5 = copi5.explode('experiences')

copi5 = copi5.reset_index()
copi5 = copi5.drop('index', axis=1)

normalized_data1 = pd.json_normalize(copi5['experiences'])

copi5 = pd.concat([copi5, normalized_data1], axis=1)

cols_a_eliminar = ['description', 'logo_url', 'ends_at', 'starts_at', 'experiences']

copi5 = copi5.drop(cols_a_eliminar, axis=1)

# %%
copi5['ends_at.day'].fillna('actualidad', inplace=True)
copi5['ends_at.month'].fillna('actualidad', inplace=True)
copi5['ends_at.year'].fillna('actualidad', inplace=True)

copi5.dropna(subset=['starts_at.day', 'starts_at.month', 'starts_at.year'], inplace=True)

copi5['Fecha inicio'] = copi5.apply(lambda x: pd.to_datetime(f"{int(x['starts_at.year'])}-{int(x['starts_at.month'])}-01"), axis=1)
copi5['Fecha fin'] = copi5.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else pd.to_datetime(f"{int(x['ends_at.year'])}-{int(x['ends_at.month'])}-01"), axis=1)

copi5['Duración (meses)'] = copi5.apply(lambda x: (datetime.datetime.now() - x['Fecha inicio']).days // 30 if x['ends_at.year'] == 'actualidad' else (x['Fecha fin'] - x['Fecha inicio']).days // 30, axis=1)

copi5['Fecha fin'] = copi5.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else x['Fecha fin'], axis=1)

copi5.drop(['location', 'starts_at.year', 'starts_at.day', 'starts_at.month', 'ends_at.day', 'ends_at.month', 'ends_at.year'], axis=1, inplace=True)

copi5.rename(columns={'company': 'Empresa', 'title': 'Puesto', 'city': 'Ciudad'}, inplace=True)

copi5 = copi5.reset_index()
copi5 = copi5.drop('index', axis=1)

# %%
copi5["Datos empresa"] = copi5["company_linkedin_profile_url"].apply(scrape_linkedin_company_data)
# Out:
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/fusi%C3%B3n-coartada/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/lor%C3%A9al/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/fundacion-universitaria-san-pablo-ceu con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/30746/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/30746/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/35649228/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/9869703/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/9869703/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2691523/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2109978/ con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/mano-estudio-de-dise%%C3%%B1o con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/lor%C3%A9al/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/ceu-business-school-madrid- con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/lor%%C3%%A9al con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/asociaci%C3%B3n-art%C3%ADstica-m%C3%BAsica-callada-a-a-m-c con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/%E5%8D%9A%E4%B8%96%E6%B1%BD%E8%BD%A6%E6%9C%8D%E5%8A%A1%E6%8A%80%E6%9C%AF-%E8%8B%8F%E5%B7%9E-%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8 con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/lor%C3%A9al/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10286204/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/18149/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/540234/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/15092653/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/563033/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.

# %%
copii5 = copi5.copy()

normalized_data1 = pd.json_normalize(copii5['Datos empresa']) 

copii5 = pd.concat([copii5, normalized_data1], axis=1) 

to_drop1 = ['linkedin_internal_id', 'specialities', 'Datos empresa', 'company_type', 'description', 'website', 'company_size', 'company_size_on_linkedin', 'founded_year', 'locations', 'name', 'tagline', 'universal_name_id', 'profile_pic_url', 'background_cover_image_url', 'search_id', 'similar_companies', 'affiliated_companies', 'updates', 'follower_count', 'acquisitions', 'exit_data', 'extra', 'funding_data', 'categories', 'hq.country', 'hq.city', 'hq.postal_code', 'hq.line_1', 'hq.is_hq', 'hq.state', 'hq']

copii5.drop(to_drop1, axis=1, inplace=True)

copii5.rename(columns={'industry': 'Sector'}, inplace=True)

new_order = ['Grado', 'Nombre completo', 'Link perfil', 'Puesto', 'Empresa', 'Sector', 'Ciudad', 'Fecha inicio', 'Fecha fin', 'Duración (meses)']

copii5 = copii5[new_order]

# %%
copii5.to_csv('/Users/davidfernandez/Desktop/clean/experience/2019-2020.csv', index=False)

# %% [markdown]
# ## Sixth dataframe: 2020-2021 class

# %%
df6 = pd.read_csv('/Users/davidfernandez/Desktop/clean/scrapped/2020-2021.csv')

df6 = df6[df6['Link perfil'] != 'Link no existente']

df6 = df6.reset_index()

df6 = df6.drop('index', axis=1)

# %%
df6["Datos escrapeados"] = df6["Link perfil"].apply(scrape_linkedin_profile2)

# %%
valor_a_buscar = {'code': 404, 'description': 'Person profile does not exist', 'name': 'Not Found'}


filas_filtradas = df6.loc[df6['Datos escrapeados'] == valor_a_buscar]

# We identify those students whose data we couldn't scrap

indices_a_eliminar = filas_filtradas.index

df6 = df6.drop(indices_a_eliminar)

# And we take them out

# %%
copi6 = df6.copy()

# %%
copi6 = copi6.reset_index()
copi6 = copi6.drop('index', axis=1)

normalized_data = pd.json_normalize(copi6['Datos escrapeados'])

copi6 = pd.concat([copi6, normalized_data], axis=1)

columnas_a_eliminar = ['Email universitario', 'Email personal', 'Datos escrapeados', 'public_identifier', 'profile_pic_url', 'first_name', 'last_name', 'full_name', 'headline', 'country', 'languages', 'education', 'occupation', 'connections', 'country_full_name', 'follower_count', 'summary', 'state', 'accomplishment_honors_awards', 'accomplishment_courses', 'accomplishment_projects', 'groups', 'accomplishment_publications', 'certifications', 'accomplishment_organisations', 'accomplishment_test_scores']

copi6 = copi6.drop(columns=columnas_a_eliminar)

copi6 = copi6.explode('experiences')

copi6 = copi6.reset_index()
copi6 = copi6.drop('index', axis=1)

normalized_data1 = pd.json_normalize(copi6['experiences'])

copi6 = pd.concat([copi6, normalized_data1], axis=1)

cols_a_eliminar = ['description', 'logo_url', 'ends_at', 'starts_at', 'experiences']

copi6 = copi6.drop(cols_a_eliminar, axis=1)

# %%
copi6['ends_at.day'].fillna('actualidad', inplace=True)
copi6['ends_at.month'].fillna('actualidad', inplace=True)
copi6['ends_at.year'].fillna('actualidad', inplace=True)

copi6.dropna(subset=['starts_at.day', 'starts_at.month', 'starts_at.year'], inplace=True)

copi6['Fecha inicio'] = copi6.apply(lambda x: pd.to_datetime(f"{int(x['starts_at.year'])}-{int(x['starts_at.month'])}-01"), axis=1)
copi6['Fecha fin'] = copi6.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else pd.to_datetime(f"{int(x['ends_at.year'])}-{int(x['ends_at.month'])}-01"), axis=1)

copi6['Duración (meses)'] = copi6.apply(lambda x: (datetime.datetime.now() - x['Fecha inicio']).days // 30 if x['ends_at.year'] == 'actualidad' else (x['Fecha fin'] - x['Fecha inicio']).days // 30, axis=1)

copi6['Fecha fin'] = copi6.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else x['Fecha fin'], axis=1)

copi6.drop(['location', 'starts_at.year', 'starts_at.day', 'starts_at.month', 'ends_at.day', 'ends_at.month', 'ends_at.year'], axis=1, inplace=True)

copi6.rename(columns={'company': 'Empresa', 'title': 'Puesto', 'city': 'Ciudad'}, inplace=True)

copi6 = copi6.reset_index()
copi6 = copi6.drop('index', axis=1)

# %%
copi6["Datos empresa"] = copi6["company_linkedin_profile_url"].apply(scrape_linkedin_company_data)
# Out:
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/psic%C3%B3logos-majadahonda/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/bamb%C3%BA-producciones/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/telecinco con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/punto-radio con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/maderas-rom%C3%A1n/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10286204/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/18149/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/540234/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/15092653/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/563033/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/non-stop-people-espa%C3%B1a con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/lor%C3%A9al/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/northgate-espa%C3%B1a/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/obrasc-n-huarte-la-n-s-a-ohl- con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.

# %%
normalized_data1 = pd.json_normalize(copi6['Datos empresa']) 

copi6 = pd.concat([copi6, normalized_data1], axis=1) 

to_drop1 = ['linkedin_internal_id', 'specialities', 'Datos empresa', 'company_type', 'description', 'website', 'company_size', 'company_size_on_linkedin', 'founded_year', 'locations', 'name', 'tagline', 'universal_name_id', 'profile_pic_url', 'background_cover_image_url', 'search_id', 'similar_companies', 'affiliated_companies', 'updates', 'follower_count', 'acquisitions', 'exit_data', 'extra', 'funding_data', 'categories', 'hq.country', 'hq.city', 'hq.postal_code', 'hq.line_1', 'hq.is_hq', 'hq.state', 'hq']

copi6.drop(to_drop1, axis=1, inplace=True)

copi6.rename(columns={'industry': 'Sector'}, inplace=True)

new_order = ['Grado', 'Nombre completo', 'Link perfil', 'Puesto', 'Empresa', 'Sector', 'Ciudad', 'Fecha inicio', 'Fecha fin', 'Duración (meses)']

copi6 = copi6[new_order]

# %%
copi6.to_csv('/Users/davidfernandez/Desktop/clean/experience/2020-2021.csv', index=False)

# %% [markdown]
# ## Seventh dataframe: 2021-2022 class

# %%
df7 = pd.read_csv('/Users/davidfernandez/Desktop/clean/scrapped/2021-2022.csv')

df7 = df7[df7['Link perfil'] != 'Link no existente']

df7 = df7.reset_index()

df7 = df7.drop('index', axis=1)

# %%
df7["Datos escrapeados"] = df7["Link perfil"].apply(scrape_linkedin_profile2)

# %%
valor_a_buscar = {'code': 404, 'description': 'Person profile does not exist', 'name': 'Not Found'}


filas_filtradas = df7.loc[df7['Datos escrapeados'] == valor_a_buscar]

# We identify those students whose data we couldn't scrap

indices_a_eliminar = filas_filtradas.index

df7 = df7.drop(indices_a_eliminar)

# And we take them out

# %%
copi7 = df7.copy()

# %%
copi7 = copi7.reset_index()
copi7 = copi7.drop('index', axis=1)

normalized_data = pd.json_normalize(copi7['Datos escrapeados'])

copi7 = pd.concat([copi7, normalized_data], axis=1)

columnas_a_eliminar = ['Email universitario', 'Email personal', 'Datos escrapeados', 'public_identifier', 'profile_pic_url', 'first_name', 'last_name', 'full_name', 'headline', 'country', 'languages', 'education', 'occupation', 'connections', 'country_full_name', 'follower_count', 'summary', 'state', 'accomplishment_honors_awards', 'accomplishment_courses', 'accomplishment_projects', 'groups', 'accomplishment_publications', 'certifications', 'accomplishment_organisations', 'accomplishment_test_scores']

copi7 = copi7.drop(columns=columnas_a_eliminar)

copi7 = copi7.explode('experiences')

copi7 = copi7.reset_index()
copi7 = copi7.drop('index', axis=1)

normalized_data1 = pd.json_normalize(copi7['experiences'])

copi7 = pd.concat([copi7, normalized_data1], axis=1)

cols_a_eliminar = ['description', 'logo_url', 'ends_at', 'starts_at', 'experiences']

copi7 = copi7.drop(cols_a_eliminar, axis=1)

# %%
copi7['ends_at.day'].fillna('actualidad', inplace=True)
copi7['ends_at.month'].fillna('actualidad', inplace=True)
copi7['ends_at.year'].fillna('actualidad', inplace=True)

copi7.dropna(subset=['starts_at.day', 'starts_at.month', 'starts_at.year'], inplace=True)

copi7['Fecha inicio'] = copi7.apply(lambda x: pd.to_datetime(f"{int(x['starts_at.year'])}-{int(x['starts_at.month'])}-01"), axis=1)
copi7['Fecha fin'] = copi7.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else pd.to_datetime(f"{int(x['ends_at.year'])}-{int(x['ends_at.month'])}-01"), axis=1)

copi7['Duración (meses)'] = copi7.apply(lambda x: (datetime.datetime.now() - x['Fecha inicio']).days // 30 if x['ends_at.year'] == 'actualidad' else (x['Fecha fin'] - x['Fecha inicio']).days // 30, axis=1)

copi7['Fecha fin'] = copi7.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else x['Fecha fin'], axis=1)

copi7.drop(['location', 'starts_at.year', 'starts_at.day', 'starts_at.month', 'ends_at.day', 'ends_at.month', 'ends_at.year'], axis=1, inplace=True)

copi7.rename(columns={'company': 'Empresa', 'title': 'Puesto', 'city': 'Ciudad'}, inplace=True)

copi7 = copi7.reset_index()
copi7 = copi7.drop('index', axis=1)

# %%
copi7["Datos empresa"] = copi7["company_linkedin_profile_url"].apply(scrape_linkedin_company_data)
# Out:
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/psic%C3%B3logos-majadahonda/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10660436/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3862919/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/mr-r%C3%ADos-&-mr-toth/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/%E5%8D%9A%E4%B8%96%E6%B1%BD%E8%BD%A6%E6%9C%8D%E5%8A%A1%E6%8A%80%E6%9C%AF-%E8%8B%8F%E5%B7%9E-%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8 con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/flying-tiger-espa%C3%B1a/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/passline-espa%C3%B1a/ con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/ministerio-de-econom%C3%ADa-industria-y-competitividad con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/fundacion-universitaria-san-pablo-ceu con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/hubceu con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/telef%C3%B3nica con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/uap-iberica-compa%C3%B1ia-de-seguros-generales-y-reaseguros-sa con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/maxxium-espa%C3%B1a-sl/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/real-f%C3%A1brica-de-tapices/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/cl%C3%ADnica-areas/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/el-espa%C3%B1ol/ con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/king%27s-college-london con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://pt.linkedin.com/company/gep-gest%C3%A3o-de-peritagens con la segunda opción.
# Error al obtener datos de https://pt.linkedin.com/company/lloyd%27s-of-london con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/keep-doing-producci%C3%B3n/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/76569998/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/40288/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1568867/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1673/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/27015171/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/42371849/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/vox-espa%C3%B1a/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/northgate-espa%C3%B1a/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/telecinco con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/lor%C3%A9al/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.

# %%
normalized_data1 = pd.json_normalize(copi7['Datos empresa']) 

copi7 = pd.concat([copi7, normalized_data1], axis=1) 

to_drop1 = ['linkedin_internal_id', 'specialities', 'Datos empresa', 'company_type', 'description', 'website', 'company_size', 'company_size_on_linkedin', 'founded_year', 'locations', 'name', 'tagline', 'universal_name_id', 'profile_pic_url', 'background_cover_image_url', 'search_id', 'similar_companies', 'affiliated_companies', 'updates', 'follower_count', 'acquisitions', 'exit_data', 'extra', 'funding_data', 'categories', 'hq.country', 'hq.city', 'hq.postal_code', 'hq.line_1', 'hq.is_hq', 'hq.state', 'hq']

copi7.drop(to_drop1, axis=1, inplace=True)

copi7.rename(columns={'industry': 'Sector'}, inplace=True)

new_order = ['Grado', 'Nombre completo', 'Link perfil', 'Puesto', 'Empresa', 'Sector', 'Ciudad', 'Fecha inicio', 'Fecha fin', 'Duración (meses)']

copi7 = copi7[new_order]

# %%
copi7.to_csv('/Users/davidfernandez/Desktop/clean/experience/2021-2022.csv', index=False)

# %% [markdown]
# ## Eight dataframe: 2022-2023 class

# %%
df8 = pd.read_csv('/Users/davidfernandez/Desktop/clean/scrapped/2022-2023.csv')

df8 = df8[df8['Link perfil'] != 'Link no existente']

df8 = df8.reset_index()

df8 = df8.drop('index', axis=1)

# %%
df8["Datos escrapeados"] = df8["Link perfil"].apply(scrape_linkedin_profile2)

# %%
valor_a_buscar = {'code': 404, 'description': 'Person profile does not exist', 'name': 'Not Found'}


filas_filtradas = df8.loc[df8['Datos escrapeados'] == valor_a_buscar]

# We identify those students whose data we couldn't scrap

indices_a_eliminar = filas_filtradas.index

df8 = df8.drop(indices_a_eliminar)

# And we take them out

# %%
copi8 = df8.copy()

# %%
copi8 = copi8.reset_index()
copi8 = copi8.drop('index', axis=1)

normalized_data = pd.json_normalize(copi8['Datos escrapeados'])

copi8 = pd.concat([copi8, normalized_data], axis=1)

columnas_a_eliminar = ['Email universitario', 'Datos escrapeados', 'public_identifier', 'profile_pic_url', 'first_name', 'last_name', 'full_name', 'headline', 'country', 'languages', 'education', 'occupation', 'connections', 'country_full_name', 'follower_count', 'summary', 'state', 'accomplishment_honors_awards', 'accomplishment_courses', 'accomplishment_projects', 'groups', 'accomplishment_publications', 'certifications', 'accomplishment_organisations', 'accomplishment_test_scores']

copi8 = copi8.drop(columns=columnas_a_eliminar)

copi8 = copi8.explode('experiences')

copi8 = copi8.reset_index()
copi8 = copi8.drop('index', axis=1)

normalized_data1 = pd.json_normalize(copi8['experiences'])

copi8 = pd.concat([copi8, normalized_data1], axis=1)

cols_a_eliminar = ['description', 'logo_url', 'ends_at', 'starts_at', 'experiences']

copi8 = copi8.drop(cols_a_eliminar, axis=1)

# %%
copi8['ends_at.day'].fillna('actualidad', inplace=True)
copi8['ends_at.month'].fillna('actualidad', inplace=True)
copi8['ends_at.year'].fillna('actualidad', inplace=True)

copi8.dropna(subset=['starts_at.day', 'starts_at.month', 'starts_at.year'], inplace=True)

copi8['Fecha inicio'] = copi8.apply(lambda x: pd.to_datetime(f"{int(x['starts_at.year'])}-{int(x['starts_at.month'])}-01"), axis=1)
copi8['Fecha fin'] = copi8.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else pd.to_datetime(f"{int(x['ends_at.year'])}-{int(x['ends_at.month'])}-01"), axis=1)

copi8['Duración (meses)'] = copi8.apply(lambda x: (datetime.datetime.now() - x['Fecha inicio']).days // 30 if x['ends_at.year'] == 'actualidad' else (x['Fecha fin'] - x['Fecha inicio']).days // 30, axis=1)

copi8['Fecha fin'] = copi8.apply(lambda x: 'actualidad' if x['ends_at.year'] == 'actualidad' else x['Fecha fin'], axis=1)

copi8.drop(['location', 'starts_at.year', 'starts_at.day', 'starts_at.month', 'ends_at.day', 'ends_at.month', 'ends_at.year'], axis=1, inplace=True)

copi8.rename(columns={'company': 'Empresa', 'title': 'Puesto', 'city': 'Ciudad'}, inplace=True)

copi8 = copi8.reset_index()
copi8 = copi8.drop('index', axis=1)

# %%
copi8["Datos empresa"] = copi8["company_linkedin_profile_url"].apply(scrape_linkedin_company_data)
# Out:
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/79893405/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/real-f%C3%A1brica-de-tapices/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/fundaci%C3%B3n-universitaria-san-pablo-unisanpablo/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/fundaci%C3%B3n-universitaria-san-pablo-unisanpablo/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/11020590/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/11020590/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/11020590/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1145368/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/18357901/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/5055702/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1483/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/37167/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/10660436/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/3862919/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2844942/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/68847691/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/6374881/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/6374881/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1044675/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/13992934/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/28626970/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/fundaci%C3%B3n-chile-espa%C3%B1a/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/540234/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/52106407/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/2850080/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/67689/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/67689/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/67689/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/86402957/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/escuela-de-esqu%C3%AD-y-snowboard-de-formigal/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/bbvaespana con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/bbvaespana con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/hospital-gregorio-mara%C3%B1%C3%B3n con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/79893405/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/11063340/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/13019884/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/115987/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/64904185/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/64904185/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/64904185/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/11028198/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/64207/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/79893405/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/15092653/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/40132126/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/73129443/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/15092653/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/hospital-central-de-la-defensa-g%C3%B3mez-ulla/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/hospital-central-de-la-defensa-g%C3%B3mez-ulla/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/casta%C3%B1o-de-indias/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/lor%C3%A9al/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/40315172/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/ctc-externalizacion con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/hubceu con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/passline-espa%C3%B1a/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/keep-doing-producci%C3%B3n/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/obrasc-n-huarte-la-n-s-a-ohl- con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/fundaci%C3%B3n-tambi%C3%A9n/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/flying-tiger-espa%C3%B1a/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/cl%C3%ADnica-areas/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/school/pontificia-universidad-cat%C3%B3lica-de-puerto-rico/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/718850/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/1973528/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/11495281/ con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/818952/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://www.linkedin.com/company/30638902/ con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de https://es.linkedin.com/company/hubceu con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.
# Error al obtener datos de None con la segunda opción.

# %%
normalized_data1 = pd.json_normalize(copi8['Datos empresa']) 

copi8 = pd.concat([copi8, normalized_data1], axis=1) 

to_drop1 = ['linkedin_internal_id', 'specialities', 'Datos empresa', 'company_type', 'description', 'website', 'company_size', 'company_size_on_linkedin', 'founded_year', 'locations', 'name', 'tagline', 'universal_name_id', 'profile_pic_url', 'background_cover_image_url', 'search_id', 'similar_companies', 'affiliated_companies', 'updates', 'follower_count', 'acquisitions', 'exit_data', 'extra', 'funding_data', 'categories', 'hq.country', 'hq.city', 'hq.postal_code', 'hq.line_1', 'hq.is_hq', 'hq.state', 'hq']

copi8.drop(to_drop1, axis=1, inplace=True)

copi8.rename(columns={'industry': 'Sector'}, inplace=True)

new_order = ['Grado', 'Nombre completo', 'Link perfil', 'Puesto', 'Empresa', 'Sector', 'Ciudad', 'Fecha inicio', 'Fecha fin', 'Duración (meses)']

copi8 = copi8[new_order]

# %%
copi8.to_csv('/Users/davidfernandez/Desktop/clean/experience/2022-2023.csv', index=False)
